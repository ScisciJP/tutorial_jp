# %% [markdown]
# # Getting Started
# Scisciの分析対象とするデータは、
#
# データベースは商業データベース（Scopusなど）とオープンアクセスデータベースがあります。OAデータベースは以下を使うことが多く、pythonのライブラリも整備されています。([pyscisci](https://github.com/SciSciCollective/pyscisci)のgithubレポジトリより引用)
#
# | Data Set      | Example |
# | ----------- | ----------- |
# | [Microsoft Academic Graph](https://docs.microsoft.com/en-us/academic-services/graph/) (MAG)      | [Getting Started with MAG](/examples/Getting_Started/Getting%20Started%20with%20MAG.ipynb)       |
# | [Clarivate Web of Science](https://clarivate.com/webofsciencegroup/solutions/web-of-science/) (WoS)   | [Getting Started with WOS](/examples/Getting_Started/Getting%20Started%20with%20WOS.ipynb)        |
# | [DBLP](https://dblp.uni-trier.de) | [Getting Started with DBLP](/examples/Getting_Started/Getting%20Started%20with%20DBLP.ipynb) |
# | [American Physical Society](https://journals.aps.org/datasets) (APS) | [Getting Started with APS](/examples/Getting_Started/Getting%20Started%20with%20APS.ipynb) |
# | [PubMed](https://www.nlm.nih.gov/databases/download/pubmed_medline.html) | [Getting Started with PubMed](/examples/Getting_Started/Getting%20Started%20with%20PubMed.ipynb) |
# | [OpenAlex](https://openalex.org/) | [Getting Started with OpenAlex](/examples/Getting_Started/Getting%20Started%20with%20OpenAlex.ipynb) |
#
# 今回は、[webサイト](https://openalex.org/)のUIも含め、初めてでも使いやすい[OpenAlex](https://docs.openalex.org/)を使って分析をします。使うライブラリは [pyalex](https://github.com/J535D165/pyalex?tab=readme-ov-file#pyalex) です。
#
# 以下のpython notebookをgoogle colaboratory などのサービス上で動かしてみてください。
#
# この章では、どのようなデータがどのような形式で取れるかをざっと確認します。

# %%
# %pip install pyalex

# より詳しい説明は https://github.com/J535D165/pyalex?tab=readme-ov-file#pyalex を参照
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyalex
#   Downloading pyalex-0.13-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in /Users/ti/Library/Python/3.9/lib/python/site-packages (from pyalex) (2.31.0)
# Requirement already satisfied: urllib3 in /Users/ti/Library/Python/3.9/lib/python/site-packages (from pyalex) (2.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ti/Library/Python/3.9/lib/python/site-packages (from requests->pyalex) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ti/Library/Python/3.9/lib/python/site-packages (from requests->pyalex) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ti/Library/Python/3.9/lib/python/site-packages (from requests->pyalex) (2023.7.22)
# Downloading pyalex-0.13-py3-none-any.whl (10 kB)
# Installing collected packages: pyalex
# Successfully installed pyalex-0.13
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pyalex import Works, Authors, Sources, Institutions, Concepts, Funders
import pyalex

# pyalex.config.email = "your@email.address"
pyalex.config.email = "zhmuler@gmail.com"
# Out:
# /Users/ti/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
from util import citation_snowball
citation_snowball("W123")
# Out:
# 'W123'

# %% [markdown]
# ## 論文のデータ

# %%
# Open Alex 総採録数
f"{Works().count():,}"
# Out:
# '248,665,581'

# %%
data = Works()["W2741809807"] # IDを指定すると論文データが一つ返る

# メタデータ
print("---------")
print(data['id']) # Open Alex内部でのID
print(data['doi']) # 論文のDOI
print(data['type']) # 論文のタイプ：article, book, editorial, letter など
print(data['publication_year']) # 論文の出版年. publication_date で日付がとれる
print(data['language']) # 論文の執筆言語
print(data['is_retracted']) # 撤回された論文かどうか
print(data['apc_list']) #APC(オープンアクセス出版料)

# 著者データ
print("---------")
print(data['authorships'][0]) # 著者データ。OpenAlexID, 共著順, 所属機関, 氏名など
print(data['institutions_distinct_count']) # 共著者がいくつの機関にまたがっているか. country_distinct_countもある

# 内容、テーマ
print("---------")
print(data['topics'][0]) # OpenAlexが割り当てたトピック。domain, field, subfieldの3階層で、subfieldに当たる分野名を記載
print(data['keywords'][0:3]) # 論文のキーワード
print(data['concepts'][0]) # OpenAlexが割り当てた概念。wikidataの分類を利用している。現在はtopicsの利用が推奨されている。

# 書誌学的情報
print("---------")
print(data['title']) # 論文のタイトル
print(data['primary_location']) # 最初に出版された媒体
print(data['cited_by_count']) # OpenAlexが再録した最新時点までの被引用数
print(data['referenced_works'][0:3]) # 参考文献

# エンティティ一覧
data.keys()

# さらに詳しくは https://docs.openalex.org/api-entities/works/work-object
# Out:
# ---------
# https://openalex.org/W2741809807
# https://doi.org/10.7717/peerj.4375
# article
# 2018
# en
# False
# {'value': 1395, 'currency': 'USD', 'value_usd': 1395, 'provenance': 'doaj'}
# ---------
# {'author_position': 'first', 'author': {'id': 'https://openalex.org/A5048491430', 'display_name': 'Heather Piwowar', 'orcid': None}, 'institutions': [{'id': 'https://openalex.org/I4210166736', 'display_name': 'Impact Technology Development (United States)', 'ror': 'https://ror.org/05ppvf150', 'country_code': 'US', 'type': 'company', 'lineage': ['https://openalex.org/I4210166736']}], 'countries': ['US'], 'is_corresponding': False, 'raw_author_name': 'Heather Piwowar', 'raw_affiliation_string': 'Impactstory, Sanford, NC, USA', 'raw_affiliation_strings': ['Impactstory, Sanford, NC, USA']}
# 7
# ---------
# {'id': 'https://openalex.org/T10102', 'display_name': 'Bibliometric Analysis and Research Evaluation', 'score': 0.9969, 'subfield': {'id': 1804, 'display_name': 'Statistics, Probability and Uncertainty'}, 'field': {'id': 18, 'display_name': 'Decision Sciences'}, 'domain': {'id': 2, 'display_name': 'Social Sciences'}}
# [{'keyword': 'access', 'score': 0.4211}, {'keyword': 'oa', 'score': 0.4145}, {'keyword': 'articles', 'score': 0.3764}]
# {'id': 'https://openalex.org/C2778805511', 'wikidata': 'https://www.wikidata.org/wiki/Q1713', 'display_name': 'Citation', 'level': 2, 'score': 0.68818974}
# ---------
# The state of OA: a large-scale analysis of the prevalence and impact of Open Access articles
# {'is_oa': True, 'landing_page_url': 'https://doi.org/10.7717/peerj.4375', 'pdf_url': 'https://peerj.com/articles/4375.pdf', 'source': {'id': 'https://openalex.org/S1983995261', 'display_name': 'PeerJ', 'issn_l': '2167-8359', 'issn': ['2167-8359'], 'is_oa': True, 'is_in_doaj': True, 'host_organization': 'https://openalex.org/P4310320104', 'host_organization_name': 'PeerJ, Inc.', 'host_organization_lineage': ['https://openalex.org/P4310320104'], 'host_organization_lineage_names': ['PeerJ, Inc.'], 'type': 'journal'}, 'license': 'cc-by', 'version': 'publishedVersion', 'is_accepted': True, 'is_published': True}
# 606
# ['https://openalex.org/W1560783210', 'https://openalex.org/W1724212071', 'https://openalex.org/W1767272795']
# dict_keys(['id', 'doi', 'title', 'display_name', 'publication_year', 'publication_date', 'ids', 'language', 'primary_location', 'type', 'type_crossref', 'indexed_in', 'open_access', 'authorships', 'countries_distinct_count', 'institutions_distinct_count', 'corresponding_author_ids', 'corresponding_institution_ids', 'apc_list', 'apc_paid', 'has_fulltext', 'cited_by_count', 'cited_by_percentile_year', 'biblio', 'is_retracted', 'is_paratext', 'primary_topic', 'topics', 'keywords', 'concepts', 'mesh', 'locations_count', 'locations', 'best_oa_location', 'sustainable_development_goals', 'grants', 'referenced_works_count', 'referenced_works', 'related_works', 'ngrams_url', 'abstract_inverted_index', 'cited_by_api_url', 'counts_by_year', 'updated_date', 'created_date'])

# %%
# 条件を指定して検索ができる。多数あってもデフォルトでは25件までしか返らない
result = Works().filter(publication_year=2020, is_oa=True).get() # 2020年に発行されたOA論文を取得
print(len(result))
list(map(lambda x: x["title"],result))
# Out:
# 25
# ['Clinical features of patients infected with 2019 novel coronavirus in Wuhan, China',
#  'Clinical Characteristics of Coronavirus Disease 2019 in China',
#  'A Novel Coronavirus from Patients with Pneumonia in China, 2019',
#  'Clinical course and risk factors for mortality of adult inpatients with COVID-19 in Wuhan, China: a retrospective cohort study',
#  'Clinical Characteristics of 138 Hospitalized Patients With 2019 Novel Coronavirus–Infected Pneumonia in Wuhan, China',
#  'A pneumonia outbreak associated with a new coronavirus of probable bat origin',
#  'SciPy 1.0: fundamental algorithms for scientific computing in Python',
#  'SARS-CoV-2 Cell Entry Depends on ACE2 and TMPRSS2 and Is Blocked by a Clinically Proven Protease Inhibitor',
#  'Cancer statistics, 2020',
#  'Epidemiological and clinical characteristics of 99 cases of 2019 novel coronavirus pneumonia in Wuhan, China: a descriptive study',
#  'Characteristics of and Important Lessons From the Coronavirus Disease 2019 (COVID-19) Outbreak in China',
#  'Early Transmission Dynamics in Wuhan, China, of Novel Coronavirus–Infected Pneumonia',
#  'Safety and Efficacy of the BNT162b2 mRNA Covid-19 Vaccine',
#  'The psychological impact of quarantine and how to reduce it: rapid review of the evidence',
#  'Array programming with NumPy',
#  'The ERA5 global reanalysis',
#  'A new coronavirus associated with human respiratory disease in China',
#  'Genomic characterisation and epidemiology of 2019 novel coronavirus: implications for virus origins and receptor binding',
#  'An interactive web-based dashboard to track COVID-19 in real time',
#  'Clinical course and outcomes of critically ill patients with SARS-CoV-2 pneumonia in Wuhan, China: a single-centered, retrospective, observational study',
#  'COVID-19: consider cytokine storm syndromes and immunosuppression',
#  'Cryo-EM structure of the 2019-nCoV spike in the prefusion conformation',
#  'Global burden of 369 diseases and injuries in 204 countries and territories, 1990–2019: a systematic analysis for the Global Burden of Disease Study 2019',
#  'Presenting Characteristics, Comorbidities, and Outcomes Among 5700 Patients Hospitalized With COVID-19 in the New York City Area',
#  'Aerosol and Surface Stability of SARS-CoV-2 as Compared with SARS-CoV-1']

# %% [markdown]
# ### 利用例
# - タイトル、アブストを検索
# - 引用文献一覧
# - ある機関から出版された論文の中で引用数の多い順に文献を取得

# %%
# タイトルとアブストラクトに含まれる文字列での検索
result = Works().search("fierce creatures").get()
# fierce および creature, creatures が含まれていれば検索結果に引っかかる
# 大文字小文字の区別は無い
# アブストラクトが取得できなかった場合に "A summary is not available for this content so..." が格納されていることがあり、
# 検索時には "summary" や "link", "provide" などでヒットするので注意が必要

pd.DataFrame(map(lambda x: [x["title"],x["abstract"]],result),
             columns=["タイトル","アブストラクト"])
# Out:
#                                                  タイトル  \
# 0   Lame Ducks or Fierce Creatures? - The Role of ...
# 1                                    Fierce creatures
# 2                   Fierce creatures : don't pet them
# 3   Fierce creatures [Newspaper columnists and the...
# 4   “Small, fierce creatures”: Mac Wellman's Aurat...
# 5                  The primitive Anglo-Saxon calendar
# 6                       Mau Mau: An African Crucible.
# 7            Middle Knowledge and the Problem of Evil
# 8                                       How many legs
# 9   Taming the Beast: Images of Trained Bears in T...
# 10        The Historical Roots of Our Ecologic Crisis
# 11                                          Free will
# 12             Dignity only for humans? A controversy
# 13                                  SEMANTIC DEMENTIA
# 14                           Whence Consumer Loyalty?
# 15  Interspecies understanding: exotic animals and...
# 16  A philosophical enquiry into the origin of our...
# 17             Wuthering Heights: The Romantic Ascent
# 18  Territoriality and Home Range Concepts as Appl...
# 19                           Whence Consumer Loyalty?
# 20  Marianne Moore's "Imperious Ox, Imperial Dish"...
# 21  “Of Monsters, Creatures and Other Queer Becomi...
# 22  Between Men: English Literature and Male Homos...
# 23                            A Future for Aesthetics
# 24                               There and Back Again
#
#                                               アブストラクト
# 0   In the pathogenesis of multiple sclerosis (MS)...
# 1   Analysis1 October 2003free access Fierce creat...
# 2                                                None
# 3                                                None
# 4   A summary is not available for this content so...
# 5   When the Anglo-Saxons invaded England, about t...
# 6   Preface. Acknowledgments. 1. There Will Be a G...
# 7   TF President Kennedy had not been shot, would ...
# 8   First Words Non-fiction is a collection of eng...
# 9   Amongst the surviving representations of bears...
# 10  A conversation with Aldous Huxley not infreque...
# 11  What is free will? Free will is the idea that ...
# 12  Should dignity be ascribed only to humans or a...
# 13  We report five patients with a stereotyped cli...
# 14  Both practitioners and academics understand th...
# 15  Abstract In February 1492 Lodovico Sforza sent...
# 16  'Pain and pleasure are simple ideas, incapable...
# 17  Wuthering Heights: The Romantic Ascent Martha ...
# 18  Journal Article Territoriality and Home Range ...
# 19  Both practitioners and academics understand th...
# 20  In the pages of her editor's Comment in Dial f...
# 21  “Of Monsters, Creatures and Other Queer Becomi...
# 22  Introductioni. Homosocial Desireii. Sexual Pol...
# 23  I have lately been admiring the engravings exe...
# 24  Even the smallest person can change the course...

# %%
# 論文の引用文献一覧
id = "W2741809807"

pager = Works().filter(cited_by=id).paginate(per_page=20)
reference = []
for page in pager:
    if len(page)>0:
        reference += list(map(lambda x: x["id"], page))
reference
# Out:
# ['https://openalex.org/W1767272795',
#  'https://openalex.org/W2016860460',
#  'https://openalex.org/W2463568293',
#  'https://openalex.org/W2048185449',
#  'https://openalex.org/W2140880926',
#  'https://openalex.org/W2089123513',
#  'https://openalex.org/W2322381034',
#  'https://openalex.org/W2115339903',
#  'https://openalex.org/W2160597895',
#  'https://openalex.org/W1560783210',
#  'https://openalex.org/W2343014812',
#  'https://openalex.org/W2003844967',
#  'https://openalex.org/W2997143876',
#  'https://openalex.org/W3121567788',
#  'https://openalex.org/W2753353163',
#  'https://openalex.org/W2588027260',
#  'https://openalex.org/W2785823074',
#  'https://openalex.org/W2587705861',
#  'https://openalex.org/W4254015553',
#  'https://openalex.org/W2029057325',
#  'https://openalex.org/W2520991028',
#  'https://openalex.org/W2231201268',
#  'https://openalex.org/W2511661767',
#  'https://openalex.org/W2306268324',
#  'https://openalex.org/W2953072907',
#  'https://openalex.org/W2031754690',
#  'https://openalex.org/W1957687230',
#  'https://openalex.org/W2563251083',
#  'https://openalex.org/W1724212071',
#  'https://openalex.org/W2566143661',
#  'https://openalex.org/W2737712680',
#  'https://openalex.org/W2345375849',
#  'https://openalex.org/W2020807482',
#  'https://openalex.org/W2078310052',
#  'https://openalex.org/W4298108315']

# %%
# ある機関から出版された論文の中で引用数の多い順に文献を取得
result = Works() \
  .filter(authorships={"institutions": {"ror": "02956yf07"}}) \
  .sort(cited_by_count="desc") \
  .get()
list(map(lambda x: x["title"], result))
# Out:
# ['A novel potent vasoconstrictor peptide produced by vascular endothelial cells',
#  'Electronic properties of two-dimensional systems',
#  'Statistical inference in vector autoregressions with possibly integrated processes',
#  'Magnetic control of ferroelectric polarization',
#  'Edge state in graphene ribbons: Nanometer size effect and edge shape dependence',
#  'An Nrf2/Small Maf Heterodimer Mediates the Induction of Phase II Detoxifying Enzyme Genes through Antioxidant Response Elements',
#  'Active sites of nitrogen-doped carbon materials for oxygen reduction reaction clarified using model catalysts',
#  'The complete genome sequence of the Gram-positive bacterium Bacillus subtilis',
#  'The 2015 World Health Organization Classification of Lung Tumors',
#  'Asian Working Group for Sarcopenia: 2019 Consensus Update on Sarcopenia Diagnosis and Treatment',
#  'Peculiar Localized State at Zigzag Graphite Edge',
#  'Cardiorespiratory Fitness as a Quantitative Predictor of All-Cause Mortality and Cardiovascular Events in Healthy Men and Women',
#  'Cloning of a cDNA encoding a non-isopeptide-selective subtype of the endothelin receptor',
#  'The human endothelin family: three structurally and pharmacologically distinct isopeptides predicted by three separate genes.',
#  'Angiotensin-converting enzyme 2 protects from severe acute lung failure',
#  'The ABC transporter Bcrp1/ABCG2 is expressed in a wide variety of stem cells and is a molecular determinant of the side-population phenotype',
#  'Exchange Monte Carlo Method and Application to Spin Glass Simulations',
#  'Long-Term Lymphohematopoietic Reconstitution by a Single CD34-Low/Negative Hematopoietic Stem Cell',
#  'Phylogenomics resolves the timing and pattern of insect evolution',
#  'Repeated temperature modulation epitaxy for p-type doping and light-emitting diode based on ZnO',
#  'Homeostatic Levels of p62 Control Cytoplasmic Inclusion Body Formation in Autophagy-Deficient Mice',
#  'Oxidative Stress Sensor Keap1 Functions as an Adaptor for Cul3-Based E3 Ligase To Regulate Proteasomal Degradation of Nrf2',
#  'Whole genome sequencing of meticillin-resistant Staphylococcus aureus',
#  'Monitoring the expression profiles of 7000 <i>Arabidopsis</i> genes under drought, cold and high‐salinity stresses using a full‐length cDNA microarray',
#  'Genome-Wide Analysis of the ERF Gene Family in Arabidopsis and Rice']

# %% [markdown]
# ## 著者のデータ

# %%
# Open Alex 総採録数
f"{Authors().count():,}"
# Out:
# '90,207,193'

# %%
data = Authors()["A5025323154"] # Authors()["https://orcid.org/0000-0002-4028-3522"]でも同じ

# 名前
print("---------")
print(data["display_name"]) # 氏名。OpenAlexで名寄せした表記揺れは display_name_alternativesにより取得可能

# メタデータ、要約データ
print("---------")
print(data["affiliations"][0]) # 著者の所属機関の全経歴（OpenAlex Institution Object）
print(data["last_known_institutions"][0]["display_name"]) # OpenAlexが把握している最新の機関（OpenAlex Institution Object）
print(data["summary_stats"]) #　2年間平均被引用数、h-index, i10indexなど

# 著作に関するデータ
print("---------")
print(data["counts_by_year"]) # 年度ごとの被引用数(年ごと)
print(data["cited_by_count"]) # 著者が得た合計の被引用数
print(data["works_count"]) # 著者が出版したarticle, letter, bookなどの合計数

# さらに詳しくは https://docs.openalex.org/api-entities/authors/author-object
# Out:
# ---------
# Albert László Barabási
# ---------
# {'institution': {'id': 'https://openalex.org/I12912129', 'ror': 'https://ror.org/04t5xt781', 'display_name': 'Northeastern University', 'country_code': 'US', 'type': 'education', 'lineage': ['https://openalex.org/I12912129']}, 'years': [2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014]}
# Harvard University
# {'2yr_mean_citedness': 2.375, 'h_index': 78, 'i10_index': 112}
# ---------
# [{'year': 2024, 'works_count': 1, 'cited_by_count': 798}, {'year': 2023, 'works_count': 11, 'cited_by_count': 7616}, {'year': 2022, 'works_count': 6, 'cited_by_count': 8431}, {'year': 2021, 'works_count': 2, 'cited_by_count': 9492}, {'year': 2020, 'works_count': 9, 'cited_by_count': 9158}, {'year': 2019, 'works_count': 9, 'cited_by_count': 8757}, {'year': 2018, 'works_count': 3, 'cited_by_count': 8278}, {'year': 2017, 'works_count': 3, 'cited_by_count': 7752}, {'year': 2016, 'works_count': 3, 'cited_by_count': 7589}, {'year': 2015, 'works_count': 6, 'cited_by_count': 7649}, {'year': 2014, 'works_count': 6, 'cited_by_count': 7274}, {'year': 2013, 'works_count': 3, 'cited_by_count': 7006}, {'year': 2012, 'works_count': 4, 'cited_by_count': 6488}]
# 92342
# 170

# %%
Authors().search_filter(display_name="einstein").get()
# Out:
# [{'id': 'https://openalex.org/A5054034686',
#   'orcid': None,
#   'display_name': 'Albert Einstein',
#   'display_name_alternatives': ['A.B Einstein',
#    'Albert. Einstein',
#    'Albert B. Einstein',
#    'A. Einstein',
#    'A. B. Einstein'],
#   'relevance_score': 11494.396,
#   'works_count': 1019,
#   'cited_by_count': 48333,
#   'summary_stats': {'2yr_mean_citedness': 0.0,
#    'h_index': 78,
#    'i10_index': 210},
#   'ids': {'openalex': 'https://openalex.org/A5054034686'},
#   'affiliations': [{'institution': {'id': 'https://openalex.org/I201646274',
#      'ror': 'https://ror.org/00cv1e222',
#      'display_name': "Saint Peter's University",
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I201646274']},
#     'years': [2024]},
#    {'institution': {'id': 'https://openalex.org/I2801107848',
#      'ror': 'https://ror.org/01j17xg39',
#      'display_name': 'New York Hospital Queens',
#      'country_code': 'US',
#      'type': 'healthcare',
#      'lineage': ['https://openalex.org/I2801107848']},
#     'years': [2021]},
#    {'institution': {'id': 'https://openalex.org/I78577930',
#      'ror': 'https://ror.org/00hj8s172',
#      'display_name': 'Columbia University',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I78577930']},
#     'years': [2021]},
#    {'institution': {'id': 'https://openalex.org/I1340179700',
#      'ror': 'https://ror.org/03gzbrs57',
#      'display_name': 'NewYork–Presbyterian Hospital',
#      'country_code': 'US',
#      'type': 'healthcare',
#      'lineage': ['https://openalex.org/I1340179700']},
#     'years': [2021]},
#    {'institution': {'id': 'https://openalex.org/I4210087414',
#      'ror': 'https://ror.org/0108yh543',
#      'display_name': 'Making View (Norway)',
#      'country_code': 'NO',
#      'type': 'company',
#      'lineage': ['https://openalex.org/I4210087414']},
#     'years': [2020, 2006, 2003, 2002, 1997, 1994]},
#    {'institution': {'id': 'https://openalex.org/I94624287',
#      'ror': 'https://ror.org/006hf6230',
#      'display_name': 'University of Twente',
#      'country_code': 'NL',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I94624287']},
#     'years': [2019, 2017]},
#    {'institution': {'id': 'https://openalex.org/I102197404',
#      'ror': 'https://ror.org/028rypz17',
#      'display_name': 'University of Paris-Sud',
#      'country_code': 'FR',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I102197404',
#       'https://openalex.org/I277688954']},
#     'years': [2013]},
#    {'institution': {'id': 'https://openalex.org/I4210145102',
#      'ror': 'https://ror.org/042tfbd02',
#      'display_name': 'Institut Polytechnique de Paris',
#      'country_code': 'FR',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I4210145102']},
#     'years': [2013]},
#    {'institution': {'id': 'https://openalex.org/I138873065',
#      'ror': 'https://ror.org/0324fzh77',
#      'display_name': 'Long Island University',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I138873065']},
#     'years': [2008]},
#    {'institution': {'id': 'https://openalex.org/I4210109571',
#      'ror': 'https://ror.org/01zbhpb91',
#      'display_name': 'Meenakshi Ammal Dental College and Hospital',
#      'country_code': 'IN',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I4210109571']},
#     'years': [2007]}],
#   'last_known_institution': {'id': 'https://openalex.org/I201646274',
#    'ror': 'https://ror.org/00cv1e222',
#    'display_name': "Saint Peter's University",
#    'country_code': 'US',
#    'type': 'education',
#    'lineage': ['https://openalex.org/I201646274']},
#   'last_known_institutions': [{'id': 'https://openalex.org/I201646274',
#     'ror': 'https://ror.org/00cv1e222',
#     'display_name': "Saint Peter's University",
#     'country_code': 'US',
#     'type': 'education',
#     'lineage': ['https://openalex.org/I201646274']}],
#   'x_concepts': [{'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 57.8},
#    {'id': 'https://openalex.org/C138885662',
#     'wikidata': 'https://www.wikidata.org/wiki/Q5891',
#     'display_name': 'Philosophy',
#     'level': 0,
#     'score': 52.1},
#    {'id': 'https://openalex.org/C62520636',
#     'wikidata': 'https://www.wikidata.org/wiki/Q944',
#     'display_name': 'Quantum mechanics',
#     'level': 1,
#     'score': 40.9},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 40.2},
#    {'id': 'https://openalex.org/C74650414',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11397',
#     'display_name': 'Classical mechanics',
#     'level': 1,
#     'score': 34.4},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 31.1},
#    {'id': 'https://openalex.org/C37914503',
#     'wikidata': 'https://www.wikidata.org/wiki/Q156495',
#     'display_name': 'Mathematical physics',
#     'level': 1,
#     'score': 27.2},
#    {'id': 'https://openalex.org/C142362112',
#     'wikidata': 'https://www.wikidata.org/wiki/Q735',
#     'display_name': 'Art',
#     'level': 0,
#     'score': 26.1},
#    {'id': 'https://openalex.org/C146846114',
#     'wikidata': 'https://www.wikidata.org/wiki/Q901448',
#     'display_name': 'Einstein',
#     'level': 2,
#     'score': 22.7},
#    {'id': 'https://openalex.org/C17744445',
#     'wikidata': 'https://www.wikidata.org/wiki/Q36442',
#     'display_name': 'Political science',
#     'level': 0,
#     'score': 22.5}],
#   'counts_by_year': [{'year': 2024, 'works_count': 1, 'cited_by_count': 186},
#    {'year': 2023, 'works_count': 4, 'cited_by_count': 1771},
#    {'year': 2022, 'works_count': 3, 'cited_by_count': 1721},
#    {'year': 2021, 'works_count': 5, 'cited_by_count': 2136},
#    {'year': 2020, 'works_count': 32, 'cited_by_count': 2076},
#    {'year': 2019, 'works_count': 6, 'cited_by_count': 2571},
#    {'year': 2018, 'works_count': 7, 'cited_by_count': 1888},
#    {'year': 2017, 'works_count': 20, 'cited_by_count': 1875},
#    {'year': 2016, 'works_count': 14, 'cited_by_count': 2018},
#    {'year': 2015, 'works_count': 32, 'cited_by_count': 2102},
#    {'year': 2014, 'works_count': 35, 'cited_by_count': 2901},
#    {'year': 2013, 'works_count': 46, 'cited_by_count': 1993},
#    {'year': 2012, 'works_count': 26, 'cited_by_count': 1879}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A5054034686',
#   'updated_date': '2024-02-10T00:25:51.739172',
#   'created_date': '2023-07-21'},
#  {'id': 'https://openalex.org/A5042867497',
#   'orcid': 'https://orcid.org/0000-0003-2583-9278',
#   'display_name': 'Andrew J. Einstein',
#   'display_name_alternatives': ['A. J. Einstein',
#    'A.J Einstein',
#    'A. Einstein',
#    'Andrew Einstein',
#    'Andrew Jeffrey Einstein',
#    'Andrew J. Einstein'],
#   'relevance_score': 4966.182,
#   'works_count': 361,
#   'cited_by_count': 12272,
#   'summary_stats': {'2yr_mean_citedness': 5.084507042253521,
#    'h_index': 52,
#    'i10_index': 146},
#   'ids': {'openalex': 'https://openalex.org/A5042867497',
#    'orcid': 'https://orcid.org/0000-0003-2583-9278'},
#   'affiliations': [{'institution': {'id': 'https://openalex.org/I2801107848',
#      'ror': 'https://ror.org/01j17xg39',
#      'display_name': 'New York Hospital Queens',
#      'country_code': 'US',
#      'type': 'healthcare',
#      'lineage': ['https://openalex.org/I2801107848']},
#     'years': [2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015]},
#    {'institution': {'id': 'https://openalex.org/I78577930',
#      'ror': 'https://ror.org/00hj8s172',
#      'display_name': 'Columbia University',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I78577930']},
#     'years': [2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015]},
#    {'institution': {'id': 'https://openalex.org/I1340179700',
#      'ror': 'https://ror.org/03gzbrs57',
#      'display_name': 'NewYork–Presbyterian Hospital',
#      'country_code': 'US',
#      'type': 'healthcare',
#      'lineage': ['https://openalex.org/I1340179700']},
#     'years': [2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015]},
#    {'institution': {'id': 'https://openalex.org/I2799503643',
#      'ror': 'https://ror.org/01esghr10',
#      'display_name': 'Columbia University Irving Medical Center',
#      'country_code': 'US',
#      'type': 'healthcare',
#      'lineage': ['https://openalex.org/I2799503643']},
#     'years': [2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015]},
#    {'institution': {'id': 'https://openalex.org/I4210096498',
#      'ror': 'https://ror.org/00n2w1t65',
#      'display_name': 'Presbyterian Hospital',
#      'country_code': 'US',
#      'type': 'healthcare',
#      'lineage': ['https://openalex.org/I1321404777',
#       'https://openalex.org/I4210096498']},
#     'years': [2023, 2021]},
#    {'institution': {'id': 'https://openalex.org/I1290900354',
#      'ror': 'https://ror.org/002hsbm82',
#      'display_name': 'Tufts Medical Center',
#      'country_code': 'US',
#      'type': 'healthcare',
#      'lineage': ['https://openalex.org/I1290900354']},
#     'years': [2022]},
#    {'institution': {'id': 'https://openalex.org/I4210146328',
#      'ror': 'https://ror.org/05kwjwj05',
#      'display_name': 'Scripps Clinic',
#      'country_code': 'US',
#      'type': 'healthcare',
#      'lineage': ['https://openalex.org/I1311914864',
#       'https://openalex.org/I4210146328']},
#     'years': [2022]},
#    {'institution': {'id': 'https://openalex.org/I4210163064',
#      'ror': 'https://ror.org/05fy98n62',
#      'display_name': 'Columbia College',
#      'country_code': 'CA',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I4210163064']},
#     'years': [2021]},
#    {'institution': {'id': 'https://openalex.org/I4210139752',
#      'ror': 'https://ror.org/04g7j1r38',
#      'display_name': 'Medical Research Associates',
#      'country_code': 'US',
#      'type': 'facility',
#      'lineage': ['https://openalex.org/I4210139752']},
#     'years': [2021]},
#    {'institution': {'id': 'https://openalex.org/I4210119835',
#      'ror': 'https://ror.org/02jv94566',
#      'display_name': 'Canon (United States)',
#      'country_code': 'US',
#      'type': 'company',
#      'lineage': ['https://openalex.org/I1320697193',
#       'https://openalex.org/I4210119835']},
#     'years': [2021]}],
#   'last_known_institution': {'id': 'https://openalex.org/I2801107848',
#    'ror': 'https://ror.org/01j17xg39',
#    'display_name': 'New York Hospital Queens',
#    'country_code': 'US',
#    'type': 'healthcare',
#    'lineage': ['https://openalex.org/I2801107848']},
#   'last_known_institutions': [{'id': 'https://openalex.org/I2801107848',
#     'ror': 'https://ror.org/01j17xg39',
#     'display_name': 'New York Hospital Queens',
#     'country_code': 'US',
#     'type': 'healthcare',
#     'lineage': ['https://openalex.org/I2801107848']},
#    {'id': 'https://openalex.org/I78577930',
#     'ror': 'https://ror.org/00hj8s172',
#     'display_name': 'Columbia University',
#     'country_code': 'US',
#     'type': 'education',
#     'lineage': ['https://openalex.org/I78577930']},
#    {'id': 'https://openalex.org/I1340179700',
#     'ror': 'https://ror.org/03gzbrs57',
#     'display_name': 'NewYork–Presbyterian Hospital',
#     'country_code': 'US',
#     'type': 'healthcare',
#     'lineage': ['https://openalex.org/I1340179700']}],
#   'x_concepts': [{'id': 'https://openalex.org/C71924100',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#     'display_name': 'Medicine',
#     'level': 0,
#     'score': 99.2},
#    {'id': 'https://openalex.org/C126322002',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11180',
#     'display_name': 'Internal medicine',
#     'level': 1,
#     'score': 80.1},
#    {'id': 'https://openalex.org/C164705383',
#     'wikidata': 'https://www.wikidata.org/wiki/Q10379',
#     'display_name': 'Cardiology',
#     'level': 1,
#     'score': 63.2},
#    {'id': 'https://openalex.org/C126838900',
#     'wikidata': 'https://www.wikidata.org/wiki/Q77604',
#     'display_name': 'Radiology',
#     'level': 1,
#     'score': 62.3},
#    {'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 49.9},
#    {'id': 'https://openalex.org/C2989005',
#     'wikidata': 'https://www.wikidata.org/wiki/Q214963',
#     'display_name': 'Nuclear medicine',
#     'level': 1,
#     'score': 44.9},
#    {'id': 'https://openalex.org/C15744967',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9418',
#     'display_name': 'Psychology',
#     'level': 0,
#     'score': 44.9},
#    {'id': 'https://openalex.org/C142724271',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7208',
#     'display_name': 'Pathology',
#     'level': 1,
#     'score': 39.9},
#    {'id': 'https://openalex.org/C141071460',
#     'wikidata': 'https://www.wikidata.org/wiki/Q40821',
#     'display_name': 'Surgery',
#     'level': 1,
#     'score': 39.6},
#    {'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 39.3},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 38.5},
#    {'id': 'https://openalex.org/C118552586',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7867',
#     'display_name': 'Psychiatry',
#     'level': 1,
#     'score': 37.4},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 31.9},
#    {'id': 'https://openalex.org/C19527891',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1120908',
#     'display_name': 'Medical physics',
#     'level': 1,
#     'score': 28.0},
#    {'id': 'https://openalex.org/C2778213512',
#     'wikidata': 'https://www.wikidata.org/wiki/Q844935',
#     'display_name': 'Coronary artery disease',
#     'level': 2,
#     'score': 26.9},
#    {'id': 'https://openalex.org/C105795698',
#     'wikidata': 'https://www.wikidata.org/wiki/Q12483',
#     'display_name': 'Statistics',
#     'level': 1,
#     'score': 25.8},
#    {'id': 'https://openalex.org/C154945302',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#     'display_name': 'Artificial intelligence',
#     'level': 1,
#     'score': 21.1},
#    {'id': 'https://openalex.org/C146957229',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1266915',
#     'display_name': 'Perfusion',
#     'level': 2,
#     'score': 20.8},
#    {'id': 'https://openalex.org/C2778405248',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1956679',
#     'display_name': 'Myocardial perfusion imaging',
#     'level': 3,
#     'score': 20.2}],
#   'counts_by_year': [{'year': 2024, 'works_count': 7, 'cited_by_count': 269},
#    {'year': 2023, 'works_count': 26, 'cited_by_count': 2750},
#    {'year': 2022, 'works_count': 35, 'cited_by_count': 2504},
#    {'year': 2021, 'works_count': 36, 'cited_by_count': 2566},
#    {'year': 2020, 'works_count': 29, 'cited_by_count': 1948},
#    {'year': 2019, 'works_count': 18, 'cited_by_count': 1540},
#    {'year': 2018, 'works_count': 25, 'cited_by_count': 1580},
#    {'year': 2017, 'works_count': 18, 'cited_by_count': 1470},
#    {'year': 2016, 'works_count': 21, 'cited_by_count': 1483},
#    {'year': 2015, 'works_count': 24, 'cited_by_count': 1508},
#    {'year': 2014, 'works_count': 25, 'cited_by_count': 1314},
#    {'year': 2013, 'works_count': 11, 'cited_by_count': 1318},
#    {'year': 2012, 'works_count': 15, 'cited_by_count': 1413}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A5042867497',
#   'updated_date': '2024-02-09T10:57:28.784585',
#   'created_date': '2023-07-21'},
#  {'id': 'https://openalex.org/A5022765499',
#   'orcid': None,
#   'display_name': 'Gilles O. Einstein',
#   'display_name_alternatives': ['G.O. Einstein',
#    'G Einstein',
#    'Gilles O. Einstein',
#    'Gilles Einstein'],
#   'relevance_score': 4587.8594,
#   'works_count': 159,
#   'cited_by_count': 10897,
#   'summary_stats': {'2yr_mean_citedness': 2.5, 'h_index': 52, 'i10_index': 87},
#   'ids': {'openalex': 'https://openalex.org/A5022765499'},
#   'affiliations': [{'institution': {'id': 'https://openalex.org/I86115722',
#      'ror': 'https://ror.org/04ytb9n23',
#      'display_name': 'Furman University',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I86115722']},
#     'years': [2021, 2020, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011]},
#    {'institution': {'id': 'https://openalex.org/I204465549',
#      'ror': 'https://ror.org/01yc7t268',
#      'display_name': 'Washington University in St. Louis',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I204465549']},
#     'years': [2021]},
#    {'institution': {'id': 'https://openalex.org/I138006243',
#      'ror': 'https://ror.org/03m2x1q45',
#      'display_name': 'University of Arizona',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I138006243',
#       'https://openalex.org/I3132585960']},
#     'years': [2021]},
#    {'institution': {'id': 'https://openalex.org/I155781252',
#      'ror': 'https://ror.org/02b6qw903',
#      'display_name': 'University of South Carolina',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I155781252',
#       'https://openalex.org/I2887101046']},
#     'years': [2014]},
#    {'institution': {'id': 'https://openalex.org/I179430373',
#      'ror': 'https://ror.org/04nv6z940',
#      'display_name': 'Greenville College',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I179430373']},
#     'years': [1991]},
#    {'institution': {'id': 'https://openalex.org/I2802236040',
#      'ror': 'https://ror.org/00jc20583',
#      'display_name': 'University of Colorado System',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I2802236040']},
#     'years': [1977, 1976]},
#    {'institution': {'id': 'https://openalex.org/I188538660',
#      'ror': 'https://ror.org/02ttsq026',
#      'display_name': 'University of Colorado Boulder',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I188538660',
#       'https://openalex.org/I2802236040']},
#     'years': [1977, 1976]}],
#   'last_known_institution': {'id': 'https://openalex.org/I86115722',
#    'ror': 'https://ror.org/04ytb9n23',
#    'display_name': 'Furman University',
#    'country_code': 'US',
#    'type': 'education',
#    'lineage': ['https://openalex.org/I86115722']},
#   'last_known_institutions': [{'id': 'https://openalex.org/I138006243',
#     'ror': 'https://ror.org/03m2x1q45',
#     'display_name': 'University of Arizona',
#     'country_code': 'US',
#     'type': 'education',
#     'lineage': ['https://openalex.org/I138006243',
#      'https://openalex.org/I3132585960']}],
#   'x_concepts': [{'id': 'https://openalex.org/C15744967',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9418',
#     'display_name': 'Psychology',
#     'level': 0,
#     'score': 93.1},
#    {'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 74.2},
#    {'id': 'https://openalex.org/C71924100',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#     'display_name': 'Medicine',
#     'level': 0,
#     'score': 71.7},
#    {'id': 'https://openalex.org/C169760540',
#     'wikidata': 'https://www.wikidata.org/wiki/Q207011',
#     'display_name': 'Neuroscience',
#     'level': 1,
#     'score': 68.6},
#    {'id': 'https://openalex.org/C118552586',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7867',
#     'display_name': 'Psychiatry',
#     'level': 1,
#     'score': 67.3},
#    {'id': 'https://openalex.org/C180747234',
#     'wikidata': 'https://www.wikidata.org/wiki/Q23373',
#     'display_name': 'Cognitive psychology',
#     'level': 1,
#     'score': 66.7},
#    {'id': 'https://openalex.org/C169900460',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2200417',
#     'display_name': 'Cognition',
#     'level': 2,
#     'score': 64.2},
#    {'id': 'https://openalex.org/C162324750',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8134',
#     'display_name': 'Economics',
#     'level': 0,
#     'score': 60.4},
#    {'id': 'https://openalex.org/C127413603',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11023',
#     'display_name': 'Engineering',
#     'level': 0,
#     'score': 58.5},
#    {'id': 'https://openalex.org/C187736073',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2920921',
#     'display_name': 'Management',
#     'level': 1,
#     'score': 56.6},
#    {'id': 'https://openalex.org/C201995342',
#     'wikidata': 'https://www.wikidata.org/wiki/Q682496',
#     'display_name': 'Systems engineering',
#     'level': 1,
#     'score': 56.0},
#    {'id': 'https://openalex.org/C2780451532',
#     'wikidata': 'https://www.wikidata.org/wiki/Q759676',
#     'display_name': 'Task (project management)',
#     'level': 2,
#     'score': 55.3},
#    {'id': 'https://openalex.org/C39628806',
#     'wikidata': 'https://www.wikidata.org/wiki/Q916150',
#     'display_name': 'Prospective memory',
#     'level': 3,
#     'score': 49.7},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 48.4},
#    {'id': 'https://openalex.org/C138885662',
#     'wikidata': 'https://www.wikidata.org/wiki/Q5891',
#     'display_name': 'Philosophy',
#     'level': 0,
#     'score': 35.2},
#    {'id': 'https://openalex.org/C41895202',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8162',
#     'display_name': 'Linguistics',
#     'level': 1,
#     'score': 30.8}],
#   'counts_by_year': [{'year': 2024, 'works_count': 0, 'cited_by_count': 42},
#    {'year': 2023, 'works_count': 0, 'cited_by_count': 360},
#    {'year': 2022, 'works_count': 0, 'cited_by_count': 436},
#    {'year': 2021, 'works_count': 2, 'cited_by_count': 435},
#    {'year': 2020, 'works_count': 1, 'cited_by_count': 552},
#    {'year': 2019, 'works_count': 1, 'cited_by_count': 549},
#    {'year': 2018, 'works_count': 2, 'cited_by_count': 525},
#    {'year': 2017, 'works_count': 11, 'cited_by_count': 544},
#    {'year': 2016, 'works_count': 2, 'cited_by_count': 597},
#    {'year': 2015, 'works_count': 4, 'cited_by_count': 545},
#    {'year': 2014, 'works_count': 6, 'cited_by_count': 573},
#    {'year': 2013, 'works_count': 6, 'cited_by_count': 658},
#    {'year': 2012, 'works_count': 9, 'cited_by_count': 534}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A5022765499',
#   'updated_date': '2024-02-10T17:36:32.350575',
#   'created_date': '2023-07-21'},
#  {'id': 'https://openalex.org/A5024186639',
#   'orcid': 'https://orcid.org/0000-0001-7422-0338',
#   'display_name': 'Mark H. Einstein',
#   'display_name_alternatives': ['M. Einstein',
#    'M. H. Einstein',
#    'Mark H. Einstein',
#    'Mark Einstein'],
#   'relevance_score': 4375.0107,
#   'works_count': 251,
#   'cited_by_count': 9333,
#   'summary_stats': {'2yr_mean_citedness': 10.789473684210526,
#    'h_index': 49,
#    'i10_index': 113},
#   'ids': {'openalex': 'https://openalex.org/A5024186639',
#    'orcid': 'https://orcid.org/0000-0001-7422-0338'},
#   'affiliations': [{'institution': {'id': 'https://openalex.org/I102322142',
#      'ror': 'https://ror.org/05vt9qd57',
#      'display_name': 'Rutgers, The State University of New Jersey',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I102322142']},
#     'years': [2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016]},
#    {'institution': {'id': 'https://openalex.org/I4210140884',
#      'ror': 'https://ror.org/040gcmg81',
#      'display_name': 'National Cancer Institute',
#      'country_code': 'US',
#      'type': 'government',
#      'lineage': ['https://openalex.org/I1299303238',
#       'https://openalex.org/I4210140884']},
#     'years': [2023, 2020, 2019, 2018, 2015, 2013]},
#    {'institution': {'id': 'https://openalex.org/I2802203029',
#      'ror': 'https://ror.org/04dpnfr42',
#      'display_name': 'Johnson University',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I2802203029']},
#     'years': [2021]},
#    {'institution': {'id': 'https://openalex.org/I180670191',
#      'ror': 'https://ror.org/043mz5j54',
#      'display_name': 'University of California, San Francisco',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I180670191',
#       'https://openalex.org/I2803209242']},
#     'years': [2020, 2013]},
#    {'institution': {'id': 'https://openalex.org/I1286490081',
#      'ror': 'https://ror.org/010b9wj87',
#      'display_name': 'Boston Medical Center',
#      'country_code': 'US',
#      'type': 'healthcare',
#      'lineage': ['https://openalex.org/I1286490081']},
#     'years': [2020, 2013]},
#    {'institution': {'id': 'https://openalex.org/I111088046',
#      'ror': 'https://ror.org/05qwgg493',
#      'display_name': 'Boston University',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I111088046']},
#     'years': [2020, 2013]},
#    {'institution': {'id': 'https://openalex.org/I4210106153',
#      'ror': 'https://ror.org/01fbdn283',
#      'display_name': 'Magee-Womens Hospital',
#      'country_code': 'US',
#      'type': 'healthcare',
#      'lineage': ['https://openalex.org/I4210106153',
#       'https://openalex.org/I4210134769']},
#     'years': [2020]},
#    {'institution': {'id': 'https://openalex.org/I170201317',
#      'ror': 'https://ror.org/01an3r305',
#      'display_name': 'University of Pittsburgh',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I170201317']},
#     'years': [2020]},
#    {'institution': {'id': 'https://openalex.org/I161318765',
#      'ror': 'https://ror.org/046rm7j60',
#      'display_name': 'University of California, Los Angeles',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I161318765',
#       'https://openalex.org/I2803209242']},
#     'years': [2020]},
#    {'institution': {'id': 'https://openalex.org/I4210137215',
#      'ror': 'https://ror.org/042s6y882',
#      'display_name': 'Inovio Pharmaceuticals (United States)',
#      'country_code': 'US',
#      'type': 'company',
#      'lineage': ['https://openalex.org/I4210137215']},
#     'years': [2020]}],
#   'last_known_institution': {'id': 'https://openalex.org/I102322142',
#    'ror': 'https://ror.org/05vt9qd57',
#    'display_name': 'Rutgers, The State University of New Jersey',
#    'country_code': 'US',
#    'type': 'education',
#    'lineage': ['https://openalex.org/I102322142']},
#   'last_known_institutions': [{'id': 'https://openalex.org/I102322142',
#     'ror': 'https://ror.org/05vt9qd57',
#     'display_name': 'Rutgers, The State University of New Jersey',
#     'country_code': 'US',
#     'type': 'education',
#     'lineage': ['https://openalex.org/I102322142']}],
#   'x_concepts': [{'id': 'https://openalex.org/C71924100',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#     'display_name': 'Medicine',
#     'level': 0,
#     'score': 101.2},
#    {'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 97.6},
#    {'id': 'https://openalex.org/C126322002',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11180',
#     'display_name': 'Internal medicine',
#     'level': 1,
#     'score': 92.4},
#    {'id': 'https://openalex.org/C54355233',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7162',
#     'display_name': 'Genetics',
#     'level': 1,
#     'score': 89.6},
#    {'id': 'https://openalex.org/C121608353',
#     'wikidata': 'https://www.wikidata.org/wiki/Q12078',
#     'display_name': 'Cancer',
#     'level': 2,
#     'score': 74.1},
#    {'id': 'https://openalex.org/C142724271',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7208',
#     'display_name': 'Pathology',
#     'level': 1,
#     'score': 67.7},
#    {'id': 'https://openalex.org/C2778220009',
#     'wikidata': 'https://www.wikidata.org/wiki/Q160105',
#     'display_name': 'Cervical cancer',
#     'level': 3,
#     'score': 45.4},
#    {'id': 'https://openalex.org/C141071460',
#     'wikidata': 'https://www.wikidata.org/wiki/Q40821',
#     'display_name': 'Surgery',
#     'level': 1,
#     'score': 39.0},
#    {'id': 'https://openalex.org/C29456083',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1221899',
#     'display_name': 'Gynecology',
#     'level': 1,
#     'score': 38.2},
#    {'id': 'https://openalex.org/C203014093',
#     'wikidata': 'https://www.wikidata.org/wiki/Q101929',
#     'display_name': 'Immunology',
#     'level': 1,
#     'score': 37.5},
#    {'id': 'https://openalex.org/C143998085',
#     'wikidata': 'https://www.wikidata.org/wiki/Q162555',
#     'display_name': 'Oncology',
#     'level': 1,
#     'score': 34.7},
#    {'id': 'https://openalex.org/C185592680',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2329',
#     'display_name': 'Chemistry',
#     'level': 0,
#     'score': 34.7},
#    {'id': 'https://openalex.org/C159047783',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7215',
#     'display_name': 'Virology',
#     'level': 1,
#     'score': 31.9},
#    {'id': 'https://openalex.org/C55493867',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7094',
#     'display_name': 'Biochemistry',
#     'level': 1,
#     'score': 27.1},
#    {'id': 'https://openalex.org/C512399662',
#     'wikidata': 'https://www.wikidata.org/wiki/Q3505712',
#     'display_name': 'Family medicine',
#     'level': 1,
#     'score': 26.7},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 23.1}],
#   'counts_by_year': [{'year': 2024, 'works_count': 3, 'cited_by_count': 178},
#    {'year': 2023, 'works_count': 32, 'cited_by_count': 2391},
#    {'year': 2022, 'works_count': 7, 'cited_by_count': 2200},
#    {'year': 2021, 'works_count': 12, 'cited_by_count': 2429},
#    {'year': 2020, 'works_count': 11, 'cited_by_count': 2620},
#    {'year': 2019, 'works_count': 9, 'cited_by_count': 2765},
#    {'year': 2018, 'works_count': 9, 'cited_by_count': 2828},
#    {'year': 2017, 'works_count': 10, 'cited_by_count': 2700},
#    {'year': 2016, 'works_count': 7, 'cited_by_count': 2602},
#    {'year': 2015, 'works_count': 18, 'cited_by_count': 2700},
#    {'year': 2014, 'works_count': 16, 'cited_by_count': 2137},
#    {'year': 2013, 'works_count': 20, 'cited_by_count': 1160},
#    {'year': 2012, 'works_count': 15, 'cited_by_count': 684}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A5024186639',
#   'updated_date': '2024-02-09T10:37:57.509862',
#   'created_date': '2023-07-21'},
#  {'id': 'https://openalex.org/A5055570312',
#   'orcid': 'https://orcid.org/0000-0003-4074-4736',
#   'display_name': 'Herbert H. Einstein',
#   'display_name_alternatives': ['Hh. Einstein',
#    'H.H Einstein',
#    'H. Einstein',
#    'Herbert H. Einstein',
#    'H. H. Einstein',
#    'Herbert H.. Einstein',
#    'Herbert Einstein'],
#   'relevance_score': 4263.738,
#   'works_count': 324,
#   'cited_by_count': 9019,
#   'summary_stats': {'2yr_mean_citedness': 3.9166666666666665,
#    'h_index': 44,
#    'i10_index': 100},
#   'ids': {'openalex': 'https://openalex.org/A5055570312',
#    'orcid': 'https://orcid.org/0000-0003-4074-4736'},
#   'affiliations': [{'institution': {'id': 'https://openalex.org/I63966007',
#      'ror': 'https://ror.org/042nb2s44',
#      'display_name': 'Massachusetts Institute of Technology',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I63966007']},
#     'years': [2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014]},
#    {'institution': {'id': 'https://openalex.org/I108468826',
#      'ror': 'https://ror.org/02z43xh36',
#      'display_name': 'Stevens Institute of Technology',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I108468826']},
#     'years': [2023]},
#    {'institution': {'id': 'https://openalex.org/I35440088',
#      'ror': 'https://ror.org/05a28rw58',
#      'display_name': 'ETH Zurich',
#      'country_code': 'CH',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I2799323385',
#       'https://openalex.org/I35440088']},
#     'years': [2021]},
#    {'institution': {'id': 'https://openalex.org/I4210110987',
#      'ror': 'https://ror.org/01wp8zh54',
#      'display_name': 'IIT@MIT',
#      'country_code': 'US',
#      'type': 'facility',
#      'lineage': ['https://openalex.org/I30771326',
#       'https://openalex.org/I4210110987']},
#     'years': [2018, 1999, 1998]},
#    {'institution': {'id': 'https://openalex.org/I1336158746',
#      'ror': 'https://ror.org/05hsggr76',
#      'display_name': 'United States International Trade Commission',
#      'country_code': 'US',
#      'type': 'government',
#      'lineage': ['https://openalex.org/I1336158746']},
#     'years': [2003]},
#    {'institution': {'id': 'https://openalex.org/I2799617873',
#      'ror': 'https://ror.org/05tmv0d13',
#      'display_name': 'American Society of Civil Engineers',
#      'country_code': 'US',
#      'type': 'nonprofit',
#      'lineage': ['https://openalex.org/I2799617873']},
#     'years': [2000]},
#    {'institution': {'id': 'https://openalex.org/I4210106689',
#      'ror': 'https://ror.org/01qpq3w78',
#      'display_name': 'Golder Associates (United States)',
#      'country_code': 'US',
#      'type': 'company',
#      'lineage': ['https://openalex.org/I176446549',
#       'https://openalex.org/I4210106689']},
#     'years': [1990]},
#    {'institution': {'id': 'https://openalex.org/I4210109586',
#      'ror': 'https://ror.org/021es5e59',
#      'display_name': 'Moscow Institute of Thermal Technology',
#      'country_code': 'RU',
#      'type': 'facility',
#      'lineage': ['https://openalex.org/I4210109586']},
#     'years': [1988]},
#    {'institution': {'id': 'https://openalex.org/I5124864',
#      'ror': 'https://ror.org/02s376052',
#      'display_name': 'École Polytechnique Fédérale de Lausanne',
#      'country_code': 'CH',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I2799323385',
#       'https://openalex.org/I5124864']},
#     'years': [1974]}],
#   'last_known_institution': {'id': 'https://openalex.org/I63966007',
#    'ror': 'https://ror.org/042nb2s44',
#    'display_name': 'Massachusetts Institute of Technology',
#    'country_code': 'US',
#    'type': 'education',
#    'lineage': ['https://openalex.org/I63966007']},
#   'last_known_institutions': [{'id': 'https://openalex.org/I63966007',
#     'ror': 'https://ror.org/042nb2s44',
#     'display_name': 'Massachusetts Institute of Technology',
#     'country_code': 'US',
#     'type': 'education',
#     'lineage': ['https://openalex.org/I63966007']}],
#   'x_concepts': [{'id': 'https://openalex.org/C127413603',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11023',
#     'display_name': 'Engineering',
#     'level': 0,
#     'score': 83.0},
#    {'id': 'https://openalex.org/C127313418',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1069',
#     'display_name': 'Geology',
#     'level': 0,
#     'score': 80.6},
#    {'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 59.3},
#    {'id': 'https://openalex.org/C187320778',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1349130',
#     'display_name': 'Geotechnical engineering',
#     'level': 1,
#     'score': 57.4},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 49.7},
#    {'id': 'https://openalex.org/C192562407',
#     'wikidata': 'https://www.wikidata.org/wiki/Q228736',
#     'display_name': 'Materials science',
#     'level': 0,
#     'score': 49.7},
#    {'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 48.1},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 44.8},
#    {'id': 'https://openalex.org/C151730666',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7205',
#     'display_name': 'Paleontology',
#     'level': 1,
#     'score': 41.0},
#    {'id': 'https://openalex.org/C159985019',
#     'wikidata': 'https://www.wikidata.org/wiki/Q181790',
#     'display_name': 'Composite material',
#     'level': 1,
#     'score': 39.5},
#    {'id': 'https://openalex.org/C62520636',
#     'wikidata': 'https://www.wikidata.org/wiki/Q944',
#     'display_name': 'Quantum mechanics',
#     'level': 1,
#     'score': 34.0},
#    {'id': 'https://openalex.org/C97355855',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11473',
#     'display_name': 'Thermodynamics',
#     'level': 1,
#     'score': 29.3},
#    {'id': 'https://openalex.org/C66938386',
#     'wikidata': 'https://www.wikidata.org/wiki/Q633538',
#     'display_name': 'Structural engineering',
#     'level': 1,
#     'score': 25.9},
#    {'id': 'https://openalex.org/C205649164',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1071',
#     'display_name': 'Geography',
#     'level': 0,
#     'score': 25.9},
#    {'id': 'https://openalex.org/C138885662',
#     'wikidata': 'https://www.wikidata.org/wiki/Q5891',
#     'display_name': 'Philosophy',
#     'level': 0,
#     'score': 20.4}],
#   'counts_by_year': [{'year': 2024, 'works_count': 0, 'cited_by_count': 141},
#    {'year': 2023, 'works_count': 17, 'cited_by_count': 1076},
#    {'year': 2022, 'works_count': 4, 'cited_by_count': 1004},
#    {'year': 2021, 'works_count': 8, 'cited_by_count': 994},
#    {'year': 2020, 'works_count': 9, 'cited_by_count': 877},
#    {'year': 2019, 'works_count': 11, 'cited_by_count': 761},
#    {'year': 2018, 'works_count': 15, 'cited_by_count': 704},
#    {'year': 2017, 'works_count': 8, 'cited_by_count': 499},
#    {'year': 2016, 'works_count': 5, 'cited_by_count': 471},
#    {'year': 2015, 'works_count': 15, 'cited_by_count': 405},
#    {'year': 2014, 'works_count': 12, 'cited_by_count': 343},
#    {'year': 2013, 'works_count': 17, 'cited_by_count': 317},
#    {'year': 2012, 'works_count': 7, 'cited_by_count': 219}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A5055570312',
#   'updated_date': '2024-02-10T04:34:13.808735',
#   'created_date': '2023-07-21'},
#  {'id': 'https://openalex.org/A5018193731',
#   'orcid': None,
#   'display_name': 'A. Einstein',
#   'display_name_alternatives': ['A. Einstein'],
#   'relevance_score': 3757.3315,
#   'works_count': 2,
#   'cited_by_count': 5064,
#   'summary_stats': {'2yr_mean_citedness': 0.0, 'h_index': 2, 'i10_index': 2},
#   'ids': {'openalex': 'https://openalex.org/A5018193731'},
#   'affiliations': [],
#   'last_known_institution': None,
#   'last_known_institutions': [],
#   'x_concepts': [{'id': 'https://openalex.org/C17744445',
#     'wikidata': 'https://www.wikidata.org/wiki/Q36442',
#     'display_name': 'Political science',
#     'level': 0,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C37914503',
#     'wikidata': 'https://www.wikidata.org/wiki/Q156495',
#     'display_name': 'Mathematical physics',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C62520636',
#     'wikidata': 'https://www.wikidata.org/wiki/Q944',
#     'display_name': 'Quantum mechanics',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C74650414',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11397',
#     'display_name': 'Classical mechanics',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C136764020',
#     'wikidata': 'https://www.wikidata.org/wiki/Q466',
#     'display_name': 'World Wide Web',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C146846114',
#     'wikidata': 'https://www.wikidata.org/wiki/Q901448',
#     'display_name': 'Einstein',
#     'level': 2,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C161191863',
#     'wikidata': 'https://www.wikidata.org/wiki/Q199655',
#     'display_name': 'Library science',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C199539241',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7748',
#     'display_name': 'Law',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C2778805511',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1713',
#     'display_name': 'Citation',
#     'level': 2,
#     'score': 100.0}],
#   'counts_by_year': [{'year': 2024, 'works_count': 0, 'cited_by_count': 25},
#    {'year': 2023, 'works_count': 0, 'cited_by_count': 183},
#    {'year': 2022, 'works_count': 0, 'cited_by_count': 207},
#    {'year': 2021, 'works_count': 0, 'cited_by_count': 250},
#    {'year': 2020, 'works_count': 0, 'cited_by_count': 217},
#    {'year': 2019, 'works_count': 0, 'cited_by_count': 219},
#    {'year': 2018, 'works_count': 0, 'cited_by_count': 255},
#    {'year': 2017, 'works_count': 0, 'cited_by_count': 192},
#    {'year': 2016, 'works_count': 0, 'cited_by_count': 195},
#    {'year': 2015, 'works_count': 0, 'cited_by_count': 186},
#    {'year': 2014, 'works_count': 0, 'cited_by_count': 229},
#    {'year': 2013, 'works_count': 0, 'cited_by_count': 175},
#    {'year': 2012, 'works_count': 0, 'cited_by_count': 142}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A5018193731',
#   'updated_date': '2024-02-09T15:50:54.679175',
#   'created_date': '2023-07-21'},
#  {'id': 'https://openalex.org/A5046690126',
#   'orcid': None,
#   'display_name': 'T. L. Einstein',
#   'display_name_alternatives': ['T. L. Einstein',
#    'T. Einstein',
#    'T.L Einstein',
#    'Tl. Einstein',
#    'Einstein Tl',
#    'Theodore Lee Einstein',
#    'Theodore Einstein',
#    'Theodore L. Einstein',
#    'T L. Einstein'],
#   'relevance_score': 3624.1162,
#   'works_count': 328,
#   'cited_by_count': 6465,
#   'summary_stats': {'2yr_mean_citedness': 0.0,
#    'h_index': 42,
#    'i10_index': 128},
#   'ids': {'openalex': 'https://openalex.org/A5046690126'},
#   'affiliations': [{'institution': {'id': 'https://openalex.org/I66946132',
#      'ror': 'https://ror.org/047s2c258',
#      'display_name': 'University of Maryland, College Park',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I1317227900',
#       'https://openalex.org/I66946132']},
#     'years': [2023, 2019, 2017, 2015, 2014, 2013, 2012, 2011, 2010, 2009]},
#    {'institution': {'id': 'https://openalex.org/I162096671',
#      'ror': 'https://ror.org/02mhbdp94',
#      'display_name': 'Universidad de Los Andes',
#      'country_code': 'CO',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I162096671']},
#     'years': [2013]},
#    {'institution': {'id': 'https://openalex.org/I171892758',
#      'ror': 'https://ror.org/02nv7yv05',
#      'display_name': 'Forschungszentrum Jülich',
#      'country_code': 'DE',
#      'type': 'facility',
#      'lineage': ['https://openalex.org/I1305996414',
#       'https://openalex.org/I171892758']},
#     'years': [2003, 1997]},
#    {'institution': {'id': 'https://openalex.org/I79576946',
#      'ror': 'https://ror.org/00b30xv10',
#      'display_name': 'University of Pennsylvania',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I79576946']},
#     'years': [2002, 1975, 1974, 1973, 1972]},
#    {'institution': {'id': 'https://openalex.org/I60134161',
#      'ror': 'https://ror.org/04chrp450',
#      'display_name': 'Nagoya University',
#      'country_code': 'JP',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I4390039267',
#       'https://openalex.org/I60134161']},
#     'years': [2000]},
#    {'institution': {'id': 'https://openalex.org/I40120149',
#      'ror': 'https://ror.org/052gg0110',
#      'display_name': 'University of Oxford',
#      'country_code': 'GB',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I40120149']},
#     'years': [1996]},
#    {'institution': {'id': 'https://openalex.org/I160013858',
#      'ror': 'https://ror.org/005ta0471',
#      'display_name': 'National Institute for Nuclear Physics',
#      'country_code': 'IT',
#      'type': 'government',
#      'lineage': ['https://openalex.org/I160013858']},
#     'years': [1993, 1992]},
#    {'institution': {'id': 'https://openalex.org/I150468666',
#      'ror': 'https://ror.org/03czfpz43',
#      'display_name': 'Emory University',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I150468666']},
#     'years': [1993]},
#    {'institution': {'id': 'https://openalex.org/I130769515',
#      'ror': 'https://ror.org/04p491231',
#      'display_name': 'Pennsylvania State University',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I130769515']},
#     'years': [1993]},
#    {'institution': {'id': 'https://openalex.org/I1321296531',
#      'ror': 'https://ror.org/05xpvk416',
#      'display_name': 'National Institute of Standards and Technology',
#      'country_code': 'US',
#      'type': 'government',
#      'lineage': ['https://openalex.org/I1321296531',
#       'https://openalex.org/I1343035065']},
#     'years': [1992, 1991]}],
#   'last_known_institution': {'id': 'https://openalex.org/I66946132',
#    'ror': 'https://ror.org/047s2c258',
#    'display_name': 'University of Maryland, College Park',
#    'country_code': 'US',
#    'type': 'education',
#    'lineage': ['https://openalex.org/I1317227900',
#     'https://openalex.org/I66946132']},
#   'last_known_institutions': [{'id': 'https://openalex.org/I66946132',
#     'ror': 'https://ror.org/047s2c258',
#     'display_name': 'University of Maryland, College Park',
#     'country_code': 'US',
#     'type': 'education',
#     'lineage': ['https://openalex.org/I1317227900',
#      'https://openalex.org/I66946132']}],
#   'x_concepts': [{'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 90.9},
#    {'id': 'https://openalex.org/C62520636',
#     'wikidata': 'https://www.wikidata.org/wiki/Q944',
#     'display_name': 'Quantum mechanics',
#     'level': 1,
#     'score': 75.9},
#    {'id': 'https://openalex.org/C185592680',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2329',
#     'display_name': 'Chemistry',
#     'level': 0,
#     'score': 66.2},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 63.7},
#    {'id': 'https://openalex.org/C192562407',
#     'wikidata': 'https://www.wikidata.org/wiki/Q228736',
#     'display_name': 'Materials science',
#     'level': 0,
#     'score': 61.0},
#    {'id': 'https://openalex.org/C178790620',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11351',
#     'display_name': 'Organic chemistry',
#     'level': 1,
#     'score': 51.5},
#    {'id': 'https://openalex.org/C26873012',
#     'wikidata': 'https://www.wikidata.org/wiki/Q214781',
#     'display_name': 'Condensed matter physics',
#     'level': 1,
#     'score': 46.3},
#    {'id': 'https://openalex.org/C2524010',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8087',
#     'display_name': 'Geometry',
#     'level': 1,
#     'score': 44.2},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 37.2},
#    {'id': 'https://openalex.org/C127413603',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11023',
#     'display_name': 'Engineering',
#     'level': 0,
#     'score': 36.6},
#    {'id': 'https://openalex.org/C97355855',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11473',
#     'display_name': 'Thermodynamics',
#     'level': 1,
#     'score': 34.1},
#    {'id': 'https://openalex.org/C121864883',
#     'wikidata': 'https://www.wikidata.org/wiki/Q677916',
# ...
#   'orcid': None,
#   'display_name': 'A. Einstein',
#   'display_name_alternatives': ['A. Einstein'],
#   'relevance_score': 1708.8788,
#   'works_count': 1,
#   'cited_by_count': 1051,
#   'summary_stats': {'2yr_mean_citedness': 0.0, 'h_index': 1, 'i10_index': 1},
#   'ids': {'openalex': 'https://openalex.org/A5029726949'},
#   'affiliations': [],
#   'last_known_institution': None,
#   'last_known_institutions': [],
#   'x_concepts': [{'id': 'https://openalex.org/C17744445',
#     'wikidata': 'https://www.wikidata.org/wiki/Q36442',
#     'display_name': 'Political science',
#     'level': 0,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C37914503',
#     'wikidata': 'https://www.wikidata.org/wiki/Q156495',
#     'display_name': 'Mathematical physics',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C62520636',
#     'wikidata': 'https://www.wikidata.org/wiki/Q944',
#     'display_name': 'Quantum mechanics',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C74650414',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11397',
#     'display_name': 'Classical mechanics',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C121332964',
#     'wikidata': 'https://www.wikidata.org/wiki/Q413',
#     'display_name': 'Physics',
#     'level': 0,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C136764020',
#     'wikidata': 'https://www.wikidata.org/wiki/Q466',
#     'display_name': 'World Wide Web',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C146846114',
#     'wikidata': 'https://www.wikidata.org/wiki/Q901448',
#     'display_name': 'Einstein',
#     'level': 2,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C161191863',
#     'wikidata': 'https://www.wikidata.org/wiki/Q199655',
#     'display_name': 'Library science',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C199539241',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7748',
#     'display_name': 'Law',
#     'level': 1,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C2778805511',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1713',
#     'display_name': 'Citation',
#     'level': 2,
#     'score': 100.0}],
#   'counts_by_year': [{'year': 2024, 'works_count': 0, 'cited_by_count': 2},
#    {'year': 2023, 'works_count': 0, 'cited_by_count': 39},
#    {'year': 2022, 'works_count': 0, 'cited_by_count': 32},
#    {'year': 2021, 'works_count': 0, 'cited_by_count': 52},
#    {'year': 2020, 'works_count': 0, 'cited_by_count': 53},
#    {'year': 2019, 'works_count': 0, 'cited_by_count': 49},
#    {'year': 2018, 'works_count': 0, 'cited_by_count': 36},
#    {'year': 2017, 'works_count': 0, 'cited_by_count': 38},
#    {'year': 2016, 'works_count': 0, 'cited_by_count': 31},
#    {'year': 2015, 'works_count': 0, 'cited_by_count': 39},
#    {'year': 2014, 'works_count': 0, 'cited_by_count': 52},
#    {'year': 2013, 'works_count': 0, 'cited_by_count': 38},
#    {'year': 2012, 'works_count': 0, 'cited_by_count': 30}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A5029726949',
#   'updated_date': '2024-02-10T09:40:26.392425',
#   'created_date': '2023-07-21'},
#  {'id': 'https://openalex.org/A5063818955',
#   'orcid': 'https://orcid.org/0000-0001-8038-6094',
#   'display_name': 'Danielle A. Einstein',
#   'display_name_alternatives': ['Danielle Einstein', 'Danielle A. Einstein'],
#   'relevance_score': 1578.6062,
#   'works_count': 24,
#   'cited_by_count': 1189,
#   'summary_stats': {'2yr_mean_citedness': 5.5, 'h_index': 12, 'i10_index': 12},
#   'ids': {'openalex': 'https://openalex.org/A5063818955',
#    'orcid': 'https://orcid.org/0000-0001-8038-6094'},
#   'affiliations': [{'institution': {'id': 'https://openalex.org/I99043593',
#      'ror': 'https://ror.org/01sf06y89',
#      'display_name': 'Macquarie University',
#      'country_code': 'AU',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I99043593']},
#     'years': [2023, 2022, 2019, 2018, 2016, 2012]},
#    {'institution': {'id': 'https://openalex.org/I2803024705',
#      'ror': 'https://ror.org/04gp5yv64',
#      'display_name': 'Westmead Hospital',
#      'country_code': 'AU',
#      'type': 'healthcare',
#      'lineage': ['https://openalex.org/I2803024705']},
#     'years': [2010, 2008, 2006, 2004, 2001, 2000]},
#    {'institution': {'id': 'https://openalex.org/I129604602',
#      'ror': 'https://ror.org/0384j8v12',
#      'display_name': 'University of Sydney',
#      'country_code': 'AU',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I129604602']},
#     'years': [2010, 2008, 2004, 2001]},
#    {'institution': {'id': 'https://openalex.org/I31746571',
#      'ror': 'https://ror.org/03r8z3t63',
#      'display_name': 'UNSW Sydney',
#      'country_code': 'AU',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I31746571']},
#     'years': [2000, 1998]}],
#   'last_known_institution': {'id': 'https://openalex.org/I99043593',
#    'ror': 'https://ror.org/01sf06y89',
#    'display_name': 'Macquarie University',
#    'country_code': 'AU',
#    'type': 'education',
#    'lineage': ['https://openalex.org/I99043593']},
#   'last_known_institutions': [{'id': 'https://openalex.org/I99043593',
#     'ror': 'https://ror.org/01sf06y89',
#     'display_name': 'Macquarie University',
#     'country_code': 'AU',
#     'type': 'education',
#     'lineage': ['https://openalex.org/I99043593']}],
#   'x_concepts': [{'id': 'https://openalex.org/C15744967',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9418',
#     'display_name': 'Psychology',
#     'level': 0,
#     'score': 100.0},
#    {'id': 'https://openalex.org/C71924100',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#     'display_name': 'Medicine',
#     'level': 0,
#     'score': 83.3},
#    {'id': 'https://openalex.org/C70410870',
#     'wikidata': 'https://www.wikidata.org/wiki/Q199906',
#     'display_name': 'Clinical psychology',
#     'level': 1,
#     'score': 79.2},
#    {'id': 'https://openalex.org/C118552586',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7867',
#     'display_name': 'Psychiatry',
#     'level': 1,
#     'score': 70.8},
#    {'id': 'https://openalex.org/C542102704',
#     'wikidata': 'https://www.wikidata.org/wiki/Q183257',
#     'display_name': 'Psychotherapist',
#     'level': 1,
#     'score': 62.5},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 50.0},
#    {'id': 'https://openalex.org/C142724271',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7208',
#     'display_name': 'Pathology',
#     'level': 1,
#     'score': 45.8},
#    {'id': 'https://openalex.org/C77805123',
#     'wikidata': 'https://www.wikidata.org/wiki/Q161272',
#     'display_name': 'Social psychology',
#     'level': 1,
#     'score': 41.7},
#    {'id': 'https://openalex.org/C138885662',
#     'wikidata': 'https://www.wikidata.org/wiki/Q5891',
#     'display_name': 'Philosophy',
#     'level': 0,
#     'score': 41.7},
#    {'id': 'https://openalex.org/C558461103',
#     'wikidata': 'https://www.wikidata.org/wiki/Q154430',
#     'display_name': 'Anxiety',
#     'level': 2,
#     'score': 41.7},
#    {'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 37.5},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 33.3},
#    {'id': 'https://openalex.org/C169760540',
#     'wikidata': 'https://www.wikidata.org/wiki/Q207011',
#     'display_name': 'Neuroscience',
#     'level': 1,
#     'score': 33.3},
#    {'id': 'https://openalex.org/C8193761',
#     'wikidata': 'https://www.wikidata.org/wiki/Q136783',
#     'display_name': 'Magical thinking',
#     'level': 3,
#     'score': 29.2},
#    {'id': 'https://openalex.org/C17744445',
#     'wikidata': 'https://www.wikidata.org/wiki/Q36442',
#     'display_name': 'Political science',
#     'level': 0,
#     'score': 29.2},
#    {'id': 'https://openalex.org/C126322002',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11180',
#     'display_name': 'Internal medicine',
#     'level': 1,
#     'score': 29.2},
#    {'id': 'https://openalex.org/C138496976',
#     'wikidata': 'https://www.wikidata.org/wiki/Q175002',
#     'display_name': 'Developmental psychology',
#     'level': 1,
#     'score': 29.2},
#    {'id': 'https://openalex.org/C199539241',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7748',
#     'display_name': 'Law',
#     'level': 1,
#     'score': 29.2},
#    {'id': 'https://openalex.org/C204787440',
#     'wikidata': 'https://www.wikidata.org/wiki/Q188504',
#     'display_name': 'Alternative medicine',
#     'level': 2,
#     'score': 29.2},
#    {'id': 'https://openalex.org/C27206212',
#     'wikidata': 'https://www.wikidata.org/wiki/Q34178',
#     'display_name': 'Theology',
#     'level': 1,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C105795698',
#     'wikidata': 'https://www.wikidata.org/wiki/Q12483',
#     'display_name': 'Statistics',
#     'level': 1,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C162324750',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8134',
#     'display_name': 'Economics',
#     'level': 0,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C169900460',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2200417',
#     'display_name': 'Cognition',
#     'level': 2,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C170477896',
#     'wikidata': 'https://www.wikidata.org/wiki/Q17039022',
#     'display_name': 'Ideation',
#     'level': 2,
#     'score': 25.0},
#    {'id': 'https://openalex.org/C188147891',
#     'wikidata': 'https://www.wikidata.org/wiki/Q147638',
#     'display_name': 'Cognitive science',
#     'level': 1,
#     'score': 25.0}],
#   'counts_by_year': [{'year': 2024, 'works_count': 0, 'cited_by_count': 20},
#    {'year': 2023, 'works_count': 2, 'cited_by_count': 200},
#    {'year': 2022, 'works_count': 2, 'cited_by_count': 176},
#    {'year': 2021, 'works_count': 0, 'cited_by_count': 115},
#    {'year': 2020, 'works_count': 0, 'cited_by_count': 88},
#    {'year': 2019, 'works_count': 1, 'cited_by_count': 48},
#    {'year': 2018, 'works_count': 1, 'cited_by_count': 35},
#    {'year': 2017, 'works_count': 0, 'cited_by_count': 41},
#    {'year': 2016, 'works_count': 1, 'cited_by_count': 49},
#    {'year': 2015, 'works_count': 0, 'cited_by_count': 38},
#    {'year': 2014, 'works_count': 1, 'cited_by_count': 91},
#    {'year': 2013, 'works_count': 0, 'cited_by_count': 63},
#    {'year': 2012, 'works_count': 1, 'cited_by_count': 58}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A5063818955',
#   'updated_date': '2024-02-09T01:15:46.834776',
#   'created_date': '2023-07-21'},
#  {'id': 'https://openalex.org/A5046260960',
#   'orcid': 'https://orcid.org/0000-0001-7487-3646',
#   'display_name': 'Katherine Levine Einstein',
#   'display_name_alternatives': ['Katherine Einstein',
#    'Katherine L. Einstein',
#    'K Einstein',
#    'Katherine Levine Einstein'],
#   'relevance_score': 1447.4994,
#   'works_count': 78,
#   'cited_by_count': 1000,
#   'summary_stats': {'2yr_mean_citedness': 1.625,
#    'h_index': 13,
#    'i10_index': 14},
#   'ids': {'openalex': 'https://openalex.org/A5046260960',
#    'orcid': 'https://orcid.org/0000-0001-7487-3646'},
#   'affiliations': [{'institution': {'id': 'https://openalex.org/I111088046',
#      'ror': 'https://ror.org/05qwgg493',
#      'display_name': 'Boston University',
#      'country_code': 'US',
#      'type': 'education',
#      'lineage': ['https://openalex.org/I111088046']},
#     'years': [2023, 2022, 2020, 2018, 2017, 2015, 2014, 2011]}],
#   'last_known_institution': {'id': 'https://openalex.org/I111088046',
#    'ror': 'https://ror.org/05qwgg493',
#    'display_name': 'Boston University',
#    'country_code': 'US',
#    'type': 'education',
#    'lineage': ['https://openalex.org/I111088046']},
#   'last_known_institutions': [{'id': 'https://openalex.org/I111088046',
#     'ror': 'https://ror.org/05qwgg493',
#     'display_name': 'Boston University',
#     'country_code': 'US',
#     'type': 'education',
#     'lineage': ['https://openalex.org/I111088046']}],
#   'x_concepts': [{'id': 'https://openalex.org/C17744445',
#     'wikidata': 'https://www.wikidata.org/wiki/Q36442',
#     'display_name': 'Political science',
#     'level': 0,
#     'score': 85.9},
#    {'id': 'https://openalex.org/C199539241',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7748',
#     'display_name': 'Law',
#     'level': 1,
#     'score': 65.4},
#    {'id': 'https://openalex.org/C144024400',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21201',
#     'display_name': 'Sociology',
#     'level': 0,
#     'score': 51.3},
#    {'id': 'https://openalex.org/C162324750',
#     'wikidata': 'https://www.wikidata.org/wiki/Q8134',
#     'display_name': 'Economics',
#     'level': 0,
#     'score': 51.3},
#    {'id': 'https://openalex.org/C94625758',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7163',
#     'display_name': 'Politics',
#     'level': 2,
#     'score': 43.6},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': 41.0},
#    {'id': 'https://openalex.org/C3116431',
#     'wikidata': 'https://www.wikidata.org/wiki/Q31728',
#     'display_name': 'Public administration',
#     'level': 1,
#     'score': 38.5},
#    {'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': 37.2},
#    {'id': 'https://openalex.org/C33923547',
#     'wikidata': 'https://www.wikidata.org/wiki/Q395',
#     'display_name': 'Mathematics',
#     'level': 0,
#     'score': 34.6},
#    {'id': 'https://openalex.org/C138885662',
#     'wikidata': 'https://www.wikidata.org/wiki/Q5891',
#     'display_name': 'Philosophy',
#     'level': 0,
#     'score': 33.3},
#    {'id': 'https://openalex.org/C15744967',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9418',
#     'display_name': 'Psychology',
#     'level': 0,
#     'score': 28.2},
#    {'id': 'https://openalex.org/C205649164',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1071',
#     'display_name': 'Geography',
#     'level': 0,
#     'score': 26.9},
#    {'id': 'https://openalex.org/C95457728',
#     'wikidata': 'https://www.wikidata.org/wiki/Q309',
#     'display_name': 'History',
#     'level': 0,
#     'score': 24.4},
#    {'id': 'https://openalex.org/C50522688',
#     'wikidata': 'https://www.wikidata.org/wiki/Q189833',
#     'display_name': 'Economic growth',
#     'level': 1,
#     'score': 23.1},
#    {'id': 'https://openalex.org/C71924100',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11190',
#     'display_name': 'Medicine',
#     'level': 0,
#     'score': 21.8},
#    {'id': 'https://openalex.org/C144133560',
#     'wikidata': 'https://www.wikidata.org/wiki/Q4830453',
#     'display_name': 'Business',
#     'level': 0,
#     'score': 20.5}],
#   'counts_by_year': [{'year': 2024, 'works_count': 0, 'cited_by_count': 20},
#    {'year': 2023, 'works_count': 3, 'cited_by_count': 157},
#    {'year': 2022, 'works_count': 4, 'cited_by_count': 162},
#    {'year': 2021, 'works_count': 4, 'cited_by_count': 221},
#    {'year': 2020, 'works_count': 11, 'cited_by_count': 219},
#    {'year': 2019, 'works_count': 15, 'cited_by_count': 90},
#    {'year': 2018, 'works_count': 8, 'cited_by_count': 65},
#    {'year': 2017, 'works_count': 4, 'cited_by_count': 44},
#    {'year': 2016, 'works_count': 8, 'cited_by_count': 22},
#    {'year': 2015, 'works_count': 10, 'cited_by_count': 8},
#    {'year': 2014, 'works_count': 6, 'cited_by_count': 0},
#    {'year': 2013, 'works_count': 3, 'cited_by_count': 0}],
#   'works_api_url': 'https://api.openalex.org/works?filter=author.id:A5046260960',
#   'updated_date': '2024-02-10T00:11:13.074184',
#   'created_date': '2023-07-21'}]

# %% [markdown]
# ## その他のデータ
# さらに、論文誌、機関、Concepts、Funderに関してデータを取得できる。

# %%
# Open Alex採録数
print(f"{Sources().count():,}") # 論文誌
print(f"{Institutions().count():,}") # 機関
print(f"{Funders().count():,}") # 出資機関
print(f"{Concepts().count():,}") # concept
# Out:
# 251,289
# 106,631
# 32,437
# 65,073

# %%
# Sources
source = Sources().filter(works_count=">1000000").get() # 100万本以上論文が出ている論文誌を取得

pd.DataFrame(map(lambda x: [x["id"],x["display_name"], x["host_organization_name"], x["is_oa"],x["works_count"]],source),
            columns=["id","論文誌名","論文誌発行機関","OA誌かどうか", "累計論文発行数"])
# Out:
#                                   id  \
# 0   https://openalex.org/S4306525036
# 1   https://openalex.org/S2764455111
# 2   https://openalex.org/S4306400806
# 3   https://openalex.org/S4306400194
# 4   https://openalex.org/S4306401280
# 5   https://openalex.org/S4306402512
# 6   https://openalex.org/S4306463937
# 7   https://openalex.org/S4306400562
# 8   https://openalex.org/S4306401271
# 9   https://openalex.org/S4210172589
# 10  https://openalex.org/S4306463091
#
#                                                  論文誌名  \
# 0                                              PubMed
# 1                                      PubMed Central
# 2                         Europe PMC (PubMed Central)
# 3                          arXiv (Cornell University)
# 4      DOAJ (DOAJ: Directory of Open Access Journals)
# 5   HAL (Le Centre pour la Communication Scientifi...
# 6                                     Springer eBooks
# 7   Zenodo (CERN European Organization for Nuclear...
# 8                 RePEc: Research Papers in Economics
# 9                     Social Science Research Network
# 10                                  De Gruyter eBooks
#
#                                            論文誌発行機関  OA誌かどうか     論文発行数
# 0                    National Institutes of Health    False  33075864
# 1                    National Institutes of Health     True   8009760
# 2                European Bioinformatics Institute     True   5316266
# 3                               Cornell University     True   3015170
# 4                                             None     True   2672478
# 5   French National Centre for Scientific Research     True   2571027
# 6                                             None    False   2519831
# 7       European Organization for Nuclear Research     True   1405433
# 8                Federal Reserve Bank of St. Louis     True   1126422
# 9                         RELX Group (Netherlands)    False   1079692
# 10                                            None    False   1075912

# %%
# Institutions
institution = Institutions().filter(country_code="JP").get() # 国コードがJP:日本の機関を取得

pd.DataFrame(map(lambda x: [x["id"],x["display_name"], x["summary_stats"]["2yr_mean_citedness"]],institution),
            columns=["id","機関名","2年間平均被引用数"])
# Out:
#                                   id  \
# 0     https://openalex.org/I74801974
# 1     https://openalex.org/I22299242
# 2     https://openalex.org/I98285908
# 3    https://openalex.org/I201537933
# 4    https://openalex.org/I135598925
# 5     https://openalex.org/I60134161
# 6    https://openalex.org/I205349734
# 7    https://openalex.org/I114531698
# 8    https://openalex.org/I146399215
# 9    https://openalex.org/I203951103
# 10   https://openalex.org/I113306721
# 11    https://openalex.org/I73613424
# 12   https://openalex.org/I161296585
# 13    https://openalex.org/I65837984
# 14   https://openalex.org/I163770644
# 15   https://openalex.org/I159385669
# 16   https://openalex.org/I150744194
# 17    https://openalex.org/I10091056
# 18  https://openalex.org/I4210086780
# 19   https://openalex.org/I104946051
# 20    https://openalex.org/I96036126
# 21    https://openalex.org/I65143321
# 22   https://openalex.org/I125602781
# 23    https://openalex.org/I71395657
# 24   https://openalex.org/I205401836
#
#                                                   機関名  2年間平均被引用数
# 0                             The University of Tokyo   3.622451
# 1                                    Kyoto University   3.246753
# 2                                    Osaka University   3.026423
# 3                                   Tohoku University   3.123361
# 4                                   Kyushu University   3.173971
# 5                                   Nagoya University   2.997435
# 6                                 Hokkaido University   3.011574
# 7                       Tokyo Institute of Technology   2.738239
# 8                               University of Tsukuba   2.645707
# 9                                     Keio University   2.989865
# 10                               Hiroshima University   3.017636
# 11  National Institute of Advanced Industrial Scie...   2.982103
# 12                        Tokyo University of Science   2.927779
# 13                                    Kobe University   2.657964
# 14                                 Okayama University   2.382826
# 15                                   Chiba University   2.636330
# 16                                  Waseda University   2.460224
# 17                                Kanazawa University   2.809774
# 18                Japan Science and Technology Agency   5.418069
# 19                                   Nihon University   2.193487
# 20                                Kumamoto University   3.140710
# 21                                    Hitachi (Japan)   1.634591
# 22                Tokyo Medical and Dental University   3.075944
# 23                                 Niigata University   2.958509
# 24           National Institute for Materials Science   6.240267

# %%
# Funders
funder_health = Funders().search_filter(display_name="health").filter(country_code="JP").get() # 名前に"health"と入っている日本の出資機関を取得

print(list(map(lambda x: x["display_name"], funder_health)))
# Out:
# ['Ministry of Health, Labour and Welfare', 'Japan Health Sciences Foundation', 'Fujita Health University', 'National Center for Global Health and Medicine', 'Daiwa Securities Health Foundation', 'National Center for Child Health and Development', 'Japan Foundation for Aging and Health', 'Global Health Innovative Technology Fund', 'Pfizer Health Research Foundation', 'University of Occupational and Environmental Health', 'Japan Health Foundation', 'Meiji Yasuda Life Foundation of Health and Welfare', 'National Institute of Occupational Safety and Health, Japan', 'Mother and Child Health Foundation', 'Fukuoka Foundation for Sound Health', 'MOA Health Science Foundation', 'Sasakawa Memorial Health Foundation', 'Niigata University of Health and Welfare', 'Juntendo Institute of Mental Health', 'Sasakawa Memorial Health Foundation', 'Yuumi Memorial Foundation for Home Health Care', 'Morinaga Foundation For Health and Nutrition', 'Mitsukoshi Health and Welfare Foundation', 'Hyogo Prefecture Health Promotion Association', 'Aichi Health Promotion Foundation']

# %%
# Concepts
results, meta = Concepts().get(return_meta=True) # OpenAlexに収録されている全てのConceptをメタ情報と共に取得
print(meta) # meta情報
print(list(map(lambda x: x["display_name"], results))) # Concept一覧、最初の25件
# Out:
# {'count': 65073, 'db_response_time_ms': 33, 'page': 1, 'per_page': 25, 'groups_count': None}
# ['Computer science', 'Medicine', 'Biology', 'Physics', 'Political science', 'Chemistry', 'Philosophy', 'Engineering', 'Mathematics', 'Psychology', 'Internal medicine', 'Art', 'Materials science', 'Geography', 'Law', 'Business', 'Humanities', 'Sociology', 'Economics', 'Quantum mechanics', 'Biochemistry', 'Artificial intelligence', 'Organic chemistry', 'Geology', 'History']
